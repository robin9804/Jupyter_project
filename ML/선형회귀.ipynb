# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#linear classifier
mnist = pd.read_csv('/content/sample_data/mnist_test.csv')

def lc_traning(x, y):
    '''
    this is linear classifier function
    '''
    result = x + y
    return result

def lc_test(x,y):
    '''
    linear classifier function test
    '''
    result = x ** y
    return result

# %%
import tensorflow as tf

a = tf.Variable()

a = tf.keras.conv2d()
