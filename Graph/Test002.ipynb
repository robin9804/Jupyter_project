# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing=pd.read_csv('/content/sample_data/california_housing_test.csv')
housing.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
plt.bar(housing['total_rooms'],housing['population'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC

# %%
data=[[0,1],[0,0],[1,1],[1,0]]
label=[0,0,0,1]
clf=LinearSVC()
clf.fit(data,label)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
test_data=[[0,0],[1,0],[0,1],[1,1]]
test_label=clf.predict(test_data)
print(test_data,"Predict result",test_label)
print('accuricy rate', accuracy_score([0,0,0,1],test_label))
# Out:
# [[0, 0], [1, 0], [0, 1], [1, 1]] Predict result [0 1 0 0]
# accuricy rate 0.5

# %% [markdown]
# accuracy는 정확도를 분석하는 메서드.
# 테스트 데이터는 [1,0] 일때만 1이 반환되도록 했다.

# %%
housing.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
plt.plot(housing['population'],label='population')
plt.plot(housing['total_rooms'],label='total rooms')
plt.title("What is new Identity and culture?")
plt.legend()
plt.show()
