# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model import enet_path
from sklearn import datasets

# %%
housing=pd.read_csv('/content/sample_data/california_housing_test.csv')
housing.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
X,y=datasets.load_diabetes(return_X_y=True)
X /= X.std(axis=0)

# %%
eps=5e-3

# %% [markdown]
# 데이터 사이즈를 정해주는 것.

# %%
alphas_enet, coefs_enet= enet_path(X,y,eps=eps,l1_ratio=0.8,fit_intercept=False)
alphas_positive_enet, coefs_positive_enet, _ =enet_path(
    X,y, l1_ratio=0.8, eps=eps, positive=True, 
)

neg_log_alphas_enet = -np.log10(alphas_enet)

# %% [markdown]
# # 데이터 만지기
# openCV 사용

# %%
for n in range(4):
  e

# %%
import cv2
from scipy import ndimage

# %%
#검출기 생성과 이미지 인식
cascade_file='frontal_face.xml'
cascade=cv2.CascadeClassifier(cascade_file)
img=cv2.imread('sample_image.jpg')

def face_detect(img):
  img_gray=cv2.cvtColor(img, cv2.COLOR_BAYER_BG2GRAY)
  face_list=cascade.detectMultiScale(img_gray, minSize=(300,300))

  for (x,y,w,h) in face_list:
    print('point of face :',x,y,w,h)
    red(0,0,255)
    cv2.rectangle(img,(x,y),(x+w,y+h),red, thickness=30)
#검출된 이미지에 상자 씌우기
