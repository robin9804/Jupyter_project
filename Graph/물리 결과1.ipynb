# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
rst=pd.read_csv("/gdrive/My Drive/Colab Notebooks/data/phy_2-rst.csv")
rst.head()
# Out:
#    Volt  125-2,re  125-2,th   125-2,F  ...   150-2,F  150,1-re  150-1,th   150-1,F
# 0     0      0.00  0.000000  0.000000  ...  0.000000      0.00  0.000000  0.000000
# 1    50      0.00  0.003473  0.034033  ...  0.048974      0.00  0.019989  0.195895
# 2   100      0.00  0.013891  0.136130  ...  0.195895      0.11  0.079957  0.783579
# 3   150      0.05  0.031254  0.306293  ...  0.440763      0.28  0.179903  1.763053
# 4   200      0.09  0.055563  0.544521  ...  0.783579      0.55  0.319828  3.134316
#
# [5 rows x 13 columns]

# %%
plt.plot(rst['Volt'],rst['125-1,re'],label="r=125mm,d=1mm")
plt.plot(rst['Volt'],rst['125-2,re'],label="r=125mm,d=2mm")
plt.plot(rst['Volt'],rst['150,1-re'],label="r=150mm,d=1mm")
plt.plot(rst['Volt'],rst['150,2-re'],label="r=150mm,d=2mm")
plt.xlabel("Volt [V]")
plt.ylabel("Mass [g]")
plt.legend()

# %%
plt.plot(rst['Volt'],rst['125-1,F'],label="r=125mm,d=1mm")
plt.plot(rst['Volt'],rst['125-2,F'],label="r=125mm,d=2mm")
plt.plot(rst['Volt'],rst['150-1,F'],label="r=150mm,d=1mm")
plt.plot(rst['Volt'],rst['150-2,F'],label="r=150mm,d=2mm")
plt.xlabel("Volt [V]")
plt.ylabel("Coulombic Force [N]")
plt.legend()
